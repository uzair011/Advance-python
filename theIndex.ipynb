# %% [markdown]
# <a href="https://colab.research.google.com/github/uzair011/Advance-python/blob/main/theIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Every Series or DataFrame has an index. it isn't just the row labels for data.
#
# =>> In practice, the index and column names are used to make sure the data is properly aligned when operating on multiple DataFrames.

# %%
url = "https://datascience.quantecon.org/assets/data/wdi_data.csv"
df = pd.read_csv(url)
df.info()
print("======= --- =======")
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      72 non-null     object
#  1   year         72 non-null     int64
#  2   GovExpend    72 non-null     float64
#  3   Consumption  72 non-null     float64
#  4   Exports      72 non-null     float64
#  5   Imports      72 non-null     float64
#  6   GDP          72 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 4.1+ KB
# ======= --- =======
#           country  year  GovExpend  Consumption   Exports   Imports        GDP
# 0          Canada  2017   0.372665     1.095475  0.582831  0.600031   1.868164
# 1          Canada  2016   0.364899     1.058426  0.576394  0.575775   1.814016
# 2          Canada  2015   0.358303     1.035208  0.568859  0.575793   1.794270
# 3          Canada  2014   0.353485     1.011988  0.550323  0.572344   1.782252
# ...

# %%
df_small = df.head(6)
df_small
# Out:
#   country  year  GovExpend  Consumption   Exports   Imports       GDP
# 0  Canada  2017   0.372665     1.095475  0.582831  0.600031  1.868164
# 1  Canada  2016   0.364899     1.058426  0.576394  0.575775  1.814016
# 2  Canada  2015   0.358303     1.035208  0.568859  0.575793  1.794270
# 3  Canada  2014   0.353485     1.011988  0.550323  0.572344  1.782252
# 4  Canada  2013   0.351541     0.986400  0.518040  0.558636  1.732714
# 5  Canada  2012   0.354342     0.961226  0.505969  0.547756  1.693428

# %%
df_selected = df.iloc[[0, 1, 3, 71], :]
df_selected
# Out:
#           country  year  GovExpend  Consumption   Exports   Imports        GDP
# 0          Canada  2017   0.372665     1.095475  0.582831  0.600031   1.868164
# 1          Canada  2016   0.364899     1.058426  0.576394  0.575775   1.814016
# 3          Canada  2014   0.353485     1.011988  0.550323  0.572344   1.782252
# 71  United States  2000   2.040500     8.272097  1.287739  1.790995  12.620268

# %%
imp_exp = df_selected[["Exports", "Imports"]]
imp_exp_copy = imp_exp.copy()
imp_exp_copy
# Out:
#      Exports   Imports
# 0   0.582831  0.600031
# 1   0.576394  0.575775
# 3   0.550323  0.572344
# 71  1.287739  1.790995

# %%
imp_exp + imp_exp_copy
# Out:
#      Exports   Imports
# 0   1.165661  1.200063
# 1   1.152787  1.151550
# 3   1.100646  1.144688
# 71  2.575478  3.581991

# %%
df_selected
# Out:
#           country  year  GovExpend  Consumption   Exports   Imports        GDP
# 0          Canada  2017   0.372665     1.095475  0.582831  0.600031   1.868164
# 1          Canada  2016   0.364899     1.058426  0.576394  0.575775   1.814016
# 3          Canada  2014   0.353485     1.011988  0.550323  0.572344   1.782252
# 71  United States  2000   2.040500     8.272097  1.287739  1.790995  12.620268

# %%
selected_impExp = df_selected + imp_exp
selected_impExp
# Out:
#     Consumption   Exports  GDP  GovExpend   Imports  country  year
# 0           NaN  1.165661  NaN        NaN  1.200063      NaN   NaN
# 1           NaN  1.152787  NaN        NaN  1.151550      NaN   NaN
# 3           NaN  1.100646  NaN        NaN  1.144688      NaN   NaN
# 71          NaN  2.575478  NaN        NaN  3.581991      NaN   NaN

# %% [markdown]
# ** Automatic Alignment. **
#
# => df_selected.loc[row, col] + imp_exp.loc[row, col]

# %% [markdown]
# **Handling Missing Data**
#
# Example, for all elements in row 1 OR columns ["country", "year", "GovExpend", "Consumption", "GDP"], the value in selected_impExp is NaN
#
# This is the way Pandas represents missing data.
#
# So, when pandas trying to look up the values in the table and could only find one vlaue in the dataFrame and other one was missing,
# then it says that the result is missing (NaN)

# %% [markdown]
# **SETTING THE INDEX**

# %%
# CREATE the dataframe
df_year = df.set_index(["year"])
df_year.head()
# Out:
#      country  GovExpend  Consumption   Exports   Imports       GDP
# year
# 2017  Canada   0.372665     1.095475  0.582831  0.600031  1.868164
# 2016  Canada   0.364899     1.058426  0.576394  0.575775  1.814016
# 2015  Canada   0.358303     1.035208  0.568859  0.575793  1.794270
# 2014  Canada   0.353485     1.011988  0.550323  0.572344  1.782252
# 2013  Canada   0.351541     0.986400  0.518040  0.558636  1.732714

# %%
# Extract all data for a specific year...
df_year.loc[2015]
# Out:
#              country  GovExpend  Consumption   Exports   Imports        GDP
# year
# 2015          Canada   0.358303     1.035208  0.568859  0.575793   1.794270
# 2015         Germany   0.706115     2.033666  1.803081  1.527074   3.718482
# 2015  United Kingdom   0.546480     1.718629  0.808384  0.872773   2.719579
# 2015   United States   2.373130    11.409800  2.222228  2.881337  16.710459

# %%
# Example, if we wanted to find the difference in the average of all the variables from a year to another year.
df_year.loc[2010].mean(numeric_only=True) - df_year.loc[2009].mean(numeric_only=True)
# Out:
# GovExpend      0.005048
# Consumption    0.056380
# Exports        0.112327
# Imports        0.133674
# GDP            0.149556
# dtype: float64

# %%
# Whats the Imports in Germany in 2012?
xyz = df_year.loc[df_year["country"] == "Germany", "Imports"].loc[2012]
print("Germany imports in 2012 is : ", xyz)
# Out:
# Germany imports in 2012 is :  1.3541216947488

# %%
# Whats the GDP in the USA and the UK in 2010?
abc = df_year.loc[df_year["country"].isin(["United States", "United Kingdom"]), "GDP"].loc[2010]
print("GDP in usa and uk in 2010 is : ")
abc
# Out:
# GDP in usa and uk in 2010 is :
# year
# 2010     2.452900
# 2010    14.992053
# Name: GDP, dtype: float64

# %%
df_year.loc[2010]
# Out:
#              country  GovExpend  Consumption   Exports   Imports        GDP
# year
# 2010          Canada   0.347332     0.921952  0.469949  0.500341   1.613543
# 2010         Germany   0.653386     1.915481  1.443735  1.266126   3.417095
# 2010  United Kingdom   0.521146     1.598563  0.690824  0.745065   2.452900
# 2010   United States   2.510143    10.185836  1.846280  2.360183  14.992053

# %% [markdown]
# **SETTING A HIERARCHICAL INDEX**
#
# Includes multiple columns in the index is advantageous in some situations...
#
# Example,
# 1. When we need more than one piece of information(column) to identify an abservation.
# 2. When we need data-alignment by more than one column.
#
# To achieve multiple columns in the index, we pass a list of multiple column names to    `set_index`

# %%
wdi = df.set_index(["country", "year"])
wdi.head(22)
# Out:
#               GovExpend  Consumption   Exports   Imports       GDP
# country year
# Canada  2017   0.372665     1.095475  0.582831  0.600031  1.868164
#         2016   0.364899     1.058426  0.576394  0.575775  1.814016
#         2015   0.358303     1.035208  0.568859  0.575793  1.794270
#         2014   0.353485     1.011988  0.550323  0.572344  1.782252
#         2013   0.351541     0.986400  0.518040  0.558636  1.732714
#         2012   0.354342     0.961226  0.505969  0.547756  1.693428
#         2011   0.351887     0.943145  0.492349  0.528227  1.664240
#         2010   0.347332     0.921952  0.469949  0.500341  1.613543
#         2009   0.339686     0.890078  0.440692  0.439796  1.565291
#         2008   0.330766     0.889602  0.506350  0.502281  1.612862
#         2007   0.318777     0.864012  0.530453  0.498002  1.596876
#         2006   0.311382     0.827643  0.524461  0.470931  1.564608
#         2005   0.303043     0.794390  0.519950  0.447222  1.524608
# ...

# %% [markdown]
# # The row lables have 2 rows.
# 1. outer (left-most) row = country
# 2. inner (right-most) row = year
#
# * When a DataFrame's index has multiple levels, we refer to the dataFrame as having hierarchical index.

# %% [markdown]
# **SLICING A HIERARCHICAL INDEX**

# %%
# Answering the previous questions in different way

# Whats the Imports in Germany in 2012?
xyz = wdi.loc[("Germany", 2012), "Imports"]
#xyz = df_year.loc[df_year["country"] == "Germany", "Imports"].loc[2012]
print("Germany imports in 2012 is : ", xyz)

print("")

# Whats the GDP in the USA and the UK in 2010?
abc = wdi.loc[(["United States", "United Kingdnom"], 2010), "GDP"]
#abc = df_year.loc[df_year["country"].isin(["United States", "United Kingdom"]), "GDP"].loc[2010]
print("GDP in usa and uk in 2010 is : \n")
abc
# Out:
# Germany imports in 2012 is :  1.3541216947488
#
# GDP in usa and uk in 2010 is :
# country         year
# United States   2010    14.992053
# United Kingdom  2010     2.452900
# Name: GDP, dtype: float64
